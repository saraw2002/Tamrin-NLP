# %% [markdown]
# <a href="https://colab.research.google.com/github/saraw2002/Tamrin-NLP/blob/master/Project(SentimentAnalysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download(["names", "stopwords", "product_reviews_1",
               "opinion_lexicon", "sentiwordnet",
               "averaged_perceptron_tagger" ,
               "vader_lexicon", "punkt"])
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package product_reviews_1 to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package product_reviews_1 is already up-to-date!
# [nltk_data] Downloading package opinion_lexicon to /root/nltk_data...
# [nltk_data]   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data] Downloading package sentiwordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/sentiwordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('product_reviews_1')
camera_reviews = product_reviews_1.reviews('Canon_G3.txt')
review = camera_reviews[0]
review.sents()[0]
# Out:
# [nltk_data] Downloading package product_reviews_1 to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping corpora/product_reviews_1.zip.
# ['i',
#  'recently',
#  'purchased',
#  'the',
#  'canon',
#  'powershot',
#  'g3',
#  'and',
#  'am',
#  'extremely',
#  'satisfied',
#  'with',
#  'the',
#  'purchase',
#  '.']

# %%
words = [w for w in nltk.corpus.product_reviews_1.words() if w.isalpha()]
print ("words = ", words[:30])
# Out:
# words =  ['repost', 'from', 'january', 'with', 'a', 'better', 'fit', 'title', 'does', 'your', 'apex', 'dvd', 'player', 'only', 'play', 'dvd', 'audio', 'without', 'video', 'or', 'does', 'it', 'play', 'audio', 'and', 'video', 'but', 'scrolling', 'in', 'black']

# %%
import pprint
stopwords = nltk.corpus.stopwords.words("english")
words = [w for w in words if w.lower() not in stopwords]
pprint.pp(words[:30],width= 50, compact = True)
# Out:
# ['repost', 'january', 'better', 'fit', 'title',
#  'apex', 'dvd', 'player', 'play', 'dvd', 'audio',
#  'without', 'video', 'play', 'audio', 'video',
#  'scrolling', 'black', 'white', 'try', 'return',
#  'player', 'waste', 'hours', 'calling', 'apex',
#  'tech', 'support', 'run', 'player']

# %%
text = "On a bright spring morning, the town square was bustling with activity. Vendors set up their stalls, offering fresh produce, handmade crafts, and delicious street food. Children played nearby, their laughter filling the air. Musicians performed lively tunes, creating a joyful atmosphere. People from all walks of life gathered, enjoying the vibrant scene and the warm, sunny weather."
pprint.pp(nltk.word_tokenize(text), width = 90, compact= True)
# Out:
# ['On', 'a', 'bright', 'spring', 'morning', ',', 'the', 'town', 'square', 'was',
#  'bustling', 'with', 'activity', '.', 'Vendors', 'set', 'up', 'their', 'stalls', ',',
#  'offering', 'fresh', 'produce', ',', 'handmade', 'crafts', ',', 'and', 'delicious',
#  'street', 'food', '.', 'Children', 'played', 'nearby', ',', 'their', 'laughter',
#  'filling', 'the', 'air', '.', 'Musicians', 'performed', 'lively', 'tunes', ',',
#  'creating', 'a', 'joyful', 'atmosphere', '.', 'People', 'from', 'all', 'walks', 'of',
#  'life', 'gathered', ',', 'enjoying', 'the', 'vibrant', 'scene', 'and', 'the', 'warm',
#  ',', 'sunny', 'weather', '.']

# %%
words : list[str] = nltk.wordpunct_tokenize(text)
fd = nltk.FreqDist(words)

# %%
print(fd.most_common(10))
fd.tabulate(10)
# Out:
# [(',', 8), ('.', 5), ('the', 4), ('a', 2), ('their', 2), ('and', 2), ('On', 1), ('bright', 1), ('spring', 1), ('morning', 1)]
#       ,       .     the       a   their     and      On  bright  spring morning
#       8       5       4       2       2       2       1       1       1       1

# %%
print(fd["THE"])
print(fd["The"])
print(fd["the"])
# Out:
# 0
# 0
# 4

# %%
lower_fd = nltk.FreqDist([w.lower() for w in fd])

# %%
text = nltk.Text(nltk.corpus.product_reviews_1.words())
text.concordance("the" , lines = 30)
# Out:
# Displaying 30 of 3565 matches:
#  and white ? before you try to return the player or waste hours calling apex te
# rs calling apex tech support , or run the player over with your car , try these
# no picture : hopefully you still have the remote control . if you tossed it out
# remote control . if you tossed it out the window , you need to fetch it . using
# window , you need to fetch it . using the remote control , press the i / p butt
# it . using the remote control , press the i / p button located on the bottom ri
# l , press the i / p button located on the bottom right corner of the remote . t
# located on the bottom right corner of the remote . the i / p button switches th
# e bottom right corner of the remote . the i / p button switches the tv display
# he remote . the i / p button switches the tv display between interlace and prog
# ogressive . if this doesnt bring back the picture , try pressing this button wi
# ...

# %%
concordance_list = text.concordance_list("bright" , lines = 50)
for entry in concordance_list:
  print(entry.line)
# Out:
# orked fine . the picture is clear , bright and sharp and the sound is good . a
# e before it focus - locks ( even in bright light ) , and the unsatisfactory li
# era . it focuses in a snap . dim or bright , it would never take a picture aft
#  easy to read and the blue light is bright enough to read at night , but dim e
# ) , the unit looks cool , screen is bright and easy to read , and the replacea
#  problems . the screen is large and bright and has all the info i need where i
# previous model , the nx , and has a bright blue backlight which illuminates th
# urmoutable obstacle . the screen is bright , easy to see in the daylight , wit
# ception - excellent sound quality - bright , visible screen - speakerphone - v
# s very light weight . the screen is bright and ring tones are unlimited . the
#  free - after - rebates phone shine bright , and commands are very responsive
# ion is very good and the colors are bright and even changeable ! the phone has

# %%
word1: list[str] = nltk.wordpunct_tokenize("""The weather in spring is nicer than in winter.
This park is nicer than the one downtown.
Her new apartment is nicer than her old one.
This restaurant is nicer than the one we went to last week.
The renovated office is nicer than the previous one.""")
text1 = nltk.Text(word1)
fd1 = text1.vocab()
fd1.tabulate(6)
# Out:
#    is nicer  than     .   one   the
#     5     5     5     5     4     3

# %%
words = [w for w in nltk.corpus.product_reviews_1.words() if w.isalpha()]
finder = nltk.collocations.TrigramCollocationFinder.from_words(words)

# %%
finder.ngram_fd.most_common(5)
# Out:
# [(('do', 'n', 't'), 104),
#  (('easy', 'to', 'use'), 48),
#  (('does', 'n', 't'), 45),
#  (('i', 'do', 'n'), 39),
#  (('did', 'n', 't'), 37)]

# %%
finder.ngram_fd.tabulate(10)
# Out:
#      ('do', 'n', 't') ('easy', 'to', 'use')    ('does', 'n', 't')      ('i', 'do', 'n')     ('did', 'n', 't')      ('wo', 'n', 't') ('you', 'have', 'to')    ('a', 'lot', 'of')    ('have', 'n', 't') ('if', 'you', 'have')
#                   104                    48                    45                    39                    37                    29                    29                    26                    26                    26

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import sentiwordnet as swn
print(swn.senti_synset('breakdown.n.03'))
list(swn.senti_synsets('slow'))
happy = swn.senti_synsets('happy', 'a')
happy0 = list(happy)[0]
happy0.pos_score()
happy0.neg_score()
happy0.obj_score()
# Out:
# <breakdown.n.03: PosScore=0.0 NegScore=0.25>
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0.125

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sent = SentimentIntensityAnalyzer()
sent.polarity_scores("OMG, Working is so hard!")
# Out:
# {'neg': 0.35, 'neu': 0.65, 'pos': 0.0, 'compound': -0.2865}

# %%
import nltk
from nltk.corpus import movie_reviews
nltk.download('movie_reviews')
movie_reviews_strings = [t.replace("://", "//") for t in movie_reviews.raw().split()]
print(movie_reviews_strings[:10])
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', 'a', 'church', 'party']

# %%
import nltk
from random import shuffle
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import movie_reviews

nltk.download('movie_reviews')
nltk.download('vader_lexicon')

sent = SentimentIntensityAnalyzer()

movie_reviews_sentences = [movie_reviews.raw(fileid) for fileid in movie_reviews.fileids()]

def is_positive(movie_review: str) -> bool:
    """True if movie_review has positive compound sentiment, False otherwise."""
    return sent.polarity_scores(movie_review)["compound"] > 0

shuffle(movie_reviews_sentences)
for review in movie_reviews_sentences[:5]:
    print(is_positive(review), "->", review)
# Out:
# True -> one of the responses those that enjoy " detroit rock city " ( probably kiss fans , mostly ) might have upon first glance at the rating i've given the film might be something like : " oh , that casey's gone and become a jaded critic on us .
# just what did he expect out of a dumb teenage rock n' roll movie like this ? "
# i'm wondering the same thing .
# i feel like i should have had a grand time with " detroit rock city . "
# it's the sort of movie i wish i could've had a lot of fun with , but i didn't .
# i just didn't .
# surely this film isn't trying to win any major awards , so should i have expected an oscar-caliber film ?
# no , but i expected something .
# a funny joke .
# a clever prank .
# a plot development .
# anything .
# the movie never delivers .
# you've got to marvel at how the filmmakers managed to come up with a movie that is truly about nothing .
# ...

# %%
positive_review_ids = nltk.corpus.movie_reviews.fileids(categories=["pos"])
negative_review_ids = nltk.corpus.movie_reviews.fileids(categories=["neg"])
all_review_ids = positive_review_ids + negative_review_ids

# %%
from statistics import mean
def is_positive(review_id: str) -> bool:
  """True if the average of all sentence compound scores is positive."""
  text = nltk.corpus.movie_reviews.raw(review_id)
  scores = [sent.polarity_scores(sentence)["compound"]
            for sentence in nltk.sent_tokenize(text)
  ]
  return mean(scores) > 0

# %%
shuffle(all_review_ids)
correct = 0
for review_id in all_review_ids:
  if is_positive(review_id):
    if review_id in positive_review_ids:
      correct += 1
    else:
      if review_id in negative_review_ids:
        correct += 1
  print(F"{correct / len(all_review_ids):.2%} correct")
# Out:
# 0.05% correct
# 0.05% correct
# 0.10% correct
# 0.15% correct
# 0.15% correct
# 0.20% correct
# 0.25% correct
# 0.30% correct
# 0.30% correct
# 0.35% correct
# 0.35% correct
# 0.35% correct
# 0.40% correct
# 0.40% correct
# 0.45% correct
# 0.50% correct
# 0.50% correct
# 0.55% correct
# 0.60% correct
# 0.65% correct
# 0.65% correct
# 0.70% correct
# 0.75% correct
# 0.75% correct
# 0.80% correct
# 0.80% correct
# 0.80% correct
# 0.85% correct
# 0.90% correct
# 0.90% correct
# 0.95% correct
# 1.00% correct
# 1.05% correct
# 1.05% correct
# 1.10% correct
# 1.10% correct
# 1.15% correct
# 1.15% correct
# 1.20% correct
# 1.25% correct
# 1.30% correct
# 1.35% correct
# 1.40% correct
# 1.40% correct
# 1.45% correct
# 1.50% correct
# 1.55% correct
# 1.60% correct
# 1.65% correct
# 1.70% correct
# 1.75% correct
# 1.80% correct
# 1.85% correct
# 1.90% correct
# 1.95% correct
# 2.00% correct
# 2.00% correct
# 2.05% correct
# 2.10% correct
# 2.10% correct
# 2.15% correct
# 2.20% correct
# ...

# %%
unwanted = nltk.corpus.stopwords.words("english")
unwanted.extend([w.lower() for w in nltk.corpus.names.words()])

def skip_unwanted(pos_tuple):
  word, tag = pos_tuple
  if not word.isalpha() or word in unwanted:
    return False
  if tag.startswith("NN"):
    return False
  return True

positive_words = [word for word, tag in filter(
    skip_unwanted,
    nltk.pos_tag(nltk.corpus.movie_reviews.words(categories=["pos"]))
)]
negative_words = [word for word, tag in filter(
    skip_unwanted, nltk.pos_tag(nltk.corpus.movie_reviews.words(categories=["neg"]))
)]

# %%
import nltk
from nltk.probability import FreqDist

positive_words = ["good", "great", "excellent", "happy", "love", "wonderful"]
negative_words = ["bad", "terrible", "poor", "sad", "hate", "awful"]

positive_fd = FreqDist(positive_words)
negative_fd = FreqDist(negative_words)

common_set = set(positive_fd).intersection(negative_fd)
for word in common_set:
    del positive_fd[word]
    del negative_fd[word]

top_100_positive = {word for word, count in positive_fd.most_common(100)}
top_100_negative = {word for word, count in negative_fd.most_common(100)}

print("Top 100 Positive Words:", top_100_positive)
print("Top 100 Negative Words:", top_100_negative)
# Out:
# Top 100 Positive Words: {'good', 'happy', 'love', 'great', 'excellent', 'wonderful'}
# Top 100 Negative Words: {'bad', 'awful', 'terrible', 'poor', 'sad', 'hate'}

# %%
import nltk
from nltk.corpus import stopwords
from nltk.collocations import BigramCollocationFinder

nltk.download('stopwords')
nltk.download('names')
nltk.download('movie_reviews')

unwanted = stopwords.words("english")
unwanted.extend([w.lower() for w in nltk.corpus.names.words()])

positive_bigram_finder = BigramCollocationFinder.from_words([
    w for w in nltk.corpus.movie_reviews.words(categories=["pos"])
    if w.isalpha() and w.lower() not in unwanted
])

negative_bigram_finder = BigramCollocationFinder.from_words([
    w for w in nltk.corpus.movie_reviews.words(categories=["neg"])
    if w.isalpha() and w.lower() not in unwanted
])

print("Top 10 Positive Bigrams:", positive_bigram_finder.nbest(nltk.collocations.BigramAssocMeasures().pmi, 10))
print("Top 10 Negative Bigrams:", negative_bigram_finder.nbest(nltk.collocations.BigramAssocMeasures().pmi, 10))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Top 10 Positive Bigrams: [('absense', 'ballot'), ('absolved', 'pearly'), ('abu', 'warda'), ('accountants', 'copywriters'), ('achilles', 'heel'), ('achin', 'breakin'), ('acupuncture', 'thang'), ('adamson', 'jenson'), ('addendum', 'postulate'), ('adhere', 'rigorously')]
# Top 10 Negative Bigrams: [('abbreviated', 'bedhopping'), ('aberration', 'incipient'), ('absurdist', 'zenith'), ('accelerates', 'snidely'), ('achilles', 'heel'), ('adeptness', 'timidity'), ('admirer', 'allred'), ('adulterer', 'initiate'), ('affability', 'contentiousness'), ('aggravated', 'harassment')]

# %%
def extract_features(text):
  features = dict()
  wordcount = 0
  compound_scores = list()
  positive_scores = list()

  for sentence in nltk.sent_tokenize(text):
    for word in nltk.word_tokenize(sentence):
      if word.lower() in top_100_positive:
        wordcount += 1

  compound_scores.append(sent.polarity_scores(sentence)["compound"])
  positive_scores.append(sent.polarity_scores(sentence)["pos"])

  features["mean_compound"] = mean(compound_scores) + 1
  features["mean_positive"] = mean(positive_scores)
  features["wordcount"] = wordcount

  return features

# %%
features = [
    (extract_features(nltk.corpus.movie_reviews.raw(review)), "pos")
    for review in nltk.corpus.movie_reviews.fileids(categories=["pos"])
]
features.extend([
    (extract_features(nltk.corpus.movie_reviews.raw(review)), "neg")
     for review in nltk.corpus.movie_reviews.fileids(categories=["pos"])
])

# %%
train_count = len(features) // 4
shuffle(features)
classifier = nltk.NaiveBayesClassifier.train(features[:train_count])
classifier.show_most_informative_features(10)
print("******")
nltk.classify.accuracy(classifier, features[train_count:])
# Out:
# Most Informative Features
#            mean_compound = 1.6369            pos : neg    =      4.8 : 1.0
#            mean_compound = 1.2732            neg : pos    =      3.1 : 1.0
#            mean_compound = 1.7429999999999999    neg : pos    =      3.1 : 1.0
#            mean_compound = 0.5412            neg : pos    =      2.4 : 1.0
#            mean_compound = 1.6486            neg : pos    =      2.4 : 1.0
#            mean_positive = 0.151             neg : pos    =      2.4 : 1.0
#            mean_positive = 0.172             neg : pos    =      2.4 : 1.0
#            mean_positive = 0.237             neg : pos    =      2.4 : 1.0
#            mean_positive = 0.186             pos : neg    =      2.2 : 1.0
#            mean_compound = 0.6599999999999999    pos : neg    =      2.2 : 1.0
# ******
# 0.4093333333333333
